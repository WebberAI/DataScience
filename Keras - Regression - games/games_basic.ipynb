# %%
import pandas as pd
from tensorflow.keras.layers import Dense, Dropout, Activation, Input
from tensorflow.keras.models import Model

base = pd.read_csv('games.csv')
base.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  ... User_Score  User_Count  Developer  Rating
# 0                Wii Sports      Wii           2006.0        Sports  ...          8       322.0   Nintendo       E
# 1         Super Mario Bros.      NES           1985.0      Platform  ...        NaN         NaN        NaN     NaN
# 2            Mario Kart Wii      Wii           2008.0        Racing  ...        8.3       709.0   Nintendo       E
# 3         Wii Sports Resort      Wii           2009.0        Sports  ...          8       192.0   Nintendo       E
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  ...        NaN         NaN        NaN     NaN
#
# [5 rows x 16 columns]

# %%
base = base.drop(['Other_Sales', 'Global_Sales', 'Developer'], axis=1)
